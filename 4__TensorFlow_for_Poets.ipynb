# %% [markdown]
# ## Train an Image Classifier with TensorFlow for Poets

# %% [markdown]
# Building a classifier that can differentiate between objects from a dataset of images.<br>
# High level code, but powerful classifier.<br><br>
#
# Build a classifier to tell the difference between different types of flowers.

# %% [markdown]
# Each column below is a feature that describes the flower:
# ![flower_features.png](attachment:flower_features.png)

# %% [markdown]
# Consider using TF Learn - A high level ML library on top of TensorFlow<br>
# - Similar to scikit-learn<br><br>
#
# TF Poets starts training by utilizing 'Inception' <br>
# - Inception is one of Google's best image classifiers
# - Open source
# - Trained on 1.2 million images from 1000 different categories
# - Took two weeks to train on an 8 GPU Workstation
